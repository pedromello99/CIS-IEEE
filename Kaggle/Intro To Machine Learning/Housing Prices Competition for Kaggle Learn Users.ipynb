# %%
import pandas as pd 
df = pd.read_csv('train.csv')
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000  ...
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000  ...
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000  ...
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     94.244521    46.660274      21.954110     3.409589    15.060959
# std     125.338794    66.256028      61.119149    29.317331    55.757415
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    25.000000       0.000000     0.000000     0.000000
# 75%     168.000000    68.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753  180921.195890
# std      40.177307    496.123024     2.703626     1.328095   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
print(df.shape)
#  Excluindo colunas com valores ausentes
df.dropna(axis=1, inplace=True)
print(df.shape)
# Out:
# (1460, 81)
# (1460, 62)

# %% [markdown]
# Define Função para cálculo rápido do melhor score de preprocessamento. <br>
# Será Testado entre: <br>
# #1 - Retirar os dados não numéricos. <br>
# #2 - Codificação Ordinal. <br>
# #3 - Codificação One Hot <br>

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
 
def model_score(X, y):
    train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=1)
    model = RandomForestRegressor(random_state=1)
    model.fit(train_X, train_y)
    preds = model.predict(val_X)
    return mean_absolute_error(val_y, preds)

# %% [markdown]
# #1 - Retirar os dados não numéricos.

# %%
# Define X and y
y = df.SalePrice
X = df.drop(['SalePrice'], axis=1).select_dtypes(exclude=['object'])

model_score(X, y)
# Out:
# 17006.18194520548

# %% [markdown]
# #2 - Codificação Ordinal.

# %%
from sklearn.preprocessing import OrdinalEncoder

object_cols = [col for col in df.columns if df[col].dtype == "object"]

y = df.SalePrice
X = df.drop(['SalePrice'], axis=1)
ordinal_encoder = OrdinalEncoder()
X[object_cols] = ordinal_encoder.fit_transform(df[object_cols])
model_score(X, y)
# Out:
# 16437.31802739726

# %% [markdown]
# #3 - Codificação One Hot <br>

# %%
from sklearn.preprocessing import OneHotEncoder

object_cols = [col for col in df.columns if df[col].dtype == "object"]
y = df.SalePrice
X = df.drop(['SalePrice'], axis=1)
OH_encoder = OneHotEncoder(handle_unknown='ignore', sparse_output=False)
OH_cols = pd.DataFrame(OH_encoder.fit_transform(df[object_cols]))
OH_cols.index = X.index
num_X = df.drop(object_cols, axis=1).drop(['SalePrice'], axis=1)
OH_X = pd.concat([num_X, OH_cols], axis=1)
OH_X.columns = [str(i) for i in OH_X.columns]
model_score(OH_X, y)
# Out:
# 16586.494547945204

# %% [markdown]
# Foi decidido utilizar o método de #2 - Codificação Ordinal. por ter um MSE mais baixo. <br>
# Com isso foi criando uma função para pré processamento dos dados:

# %%
def preprocess(df):
    object_cols = [col for col in df.columns if df[col].dtype == "object"]

    y = df.SalePrice
    X = df.drop(['SalePrice'], axis=1)
    ordinal_encoder = OrdinalEncoder()
    X[object_cols] = ordinal_encoder.fit_transform(df[object_cols])
    return X, y

# %% [markdown]
# Testar modelo de arvore de decisão

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

X, y = preprocess(df)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
dt = DecisionTreeRegressor(random_state=0)
dt.fit(X_train, y_train)
y_pred = dt.predict(X_test)
print('MSE: ', mean_absolute_error(y_test, y_pred))
# Out:
# MSE:  25057.701369863014

# %% [markdown]
# Será Utilizado o a Biblioteca Pycarte para comparar os modelos de aprendizado de máquina #pip install pycaret (reqs: python<3.8) <br>

# %%
from pycaret.regression import *
X, y = preprocess(df)
X['SalePrice'] = y
exp_reg = setup(data = X, target = 'SalePrice', session_id=123, normalize = True, transformation = True)
# Out:
# <style type="text/css">
# #T_2daa4_row8_col1, #T_2daa4_row12_col1, #T_2daa4_row14_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2daa4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2daa4_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_2daa4_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2daa4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2daa4_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_2daa4_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_2daa4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2daa4_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_2daa4_row1_col1" class="data row1 col1" >SalePrice</td>
#     </tr>
#     <tr>
#       <th id="T_2daa4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2daa4_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_2daa4_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_2daa4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2daa4_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_2daa4_row3_col1" class="data row3 col1" >(1460, 62)</td>
#     </tr>
#     <tr>
#       <th id="T_2daa4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2daa4_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_2daa4_row4_col1" class="data row4 col1" >(1460, 62)</td>
#     </tr>
#     <tr>
#       <th id="T_2daa4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2daa4_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_2daa4_row5_col1" class="data row5 col1" >(1021, 62)</td>
#     </tr>
#     <tr>
#       <th id="T_2daa4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2daa4_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_2daa4_row6_col1" class="data row6 col1" >(439, 62)</td>
#     </tr>
#     <tr>
#       <th id="T_2daa4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2daa4_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_2daa4_row7_col1" class="data row7 col1" >61</td>
#     </tr>
#     <tr>
#       <th id="T_2daa4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2daa4_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_2daa4_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2daa4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2daa4_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_2daa4_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_2daa4_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_2daa4_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_2daa4_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_2daa4_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_2daa4_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_2daa4_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_2daa4_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_2daa4_row12_col0" class="data row12 col0" >Transformation</td>
#       <td id="T_2daa4_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2daa4_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_2daa4_row13_col0" class="data row13 col0" >Transformation method</td>
#       <td id="T_2daa4_row13_col1" class="data row13 col1" >yeo-johnson</td>
#     </tr>
#     <tr>
#       <th id="T_2daa4_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_2daa4_row14_col0" class="data row14 col0" >Normalize</td>
#       <td id="T_2daa4_row14_col1" class="data row14 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2daa4_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_2daa4_row15_col0" class="data row15 col0" >Normalize method</td>
#       <td id="T_2daa4_row15_col1" class="data row15 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_2daa4_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_2daa4_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_2daa4_row16_col1" class="data row16 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_2daa4_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_2daa4_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_2daa4_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_2daa4_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_2daa4_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_2daa4_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_2daa4_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_2daa4_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_2daa4_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2daa4_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_2daa4_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_2daa4_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2daa4_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_2daa4_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_2daa4_row21_col1" class="data row21 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_2daa4_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_2daa4_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_2daa4_row22_col1" class="data row22 col1" >9874</td>
#     </tr>
#   </tbody>
# </table>

# %%
exp_reg.compare_models()
# Out:
# <style type="text/css">
# #T_9ea6b th {
#   text-align: left;
# }
# #T_9ea6b_row0_col0, #T_9ea6b_row1_col0, #T_9ea6b_row1_col1, #T_9ea6b_row1_col2, #T_9ea6b_row1_col3, #T_9ea6b_row1_col4, #T_9ea6b_row1_col5, #T_9ea6b_row1_col6, #T_9ea6b_row2_col0, #T_9ea6b_row2_col1, #T_9ea6b_row2_col2, #T_9ea6b_row2_col3, #T_9ea6b_row2_col4, #T_9ea6b_row2_col5, #T_9ea6b_row2_col6, #T_9ea6b_row3_col0, #T_9ea6b_row3_col1, #T_9ea6b_row3_col2, #T_9ea6b_row3_col3, #T_9ea6b_row3_col4, #T_9ea6b_row3_col5, #T_9ea6b_row3_col6, #T_9ea6b_row4_col0, #T_9ea6b_row4_col1, #T_9ea6b_row4_col2, #T_9ea6b_row4_col3, #T_9ea6b_row4_col4, #T_9ea6b_row4_col5, #T_9ea6b_row4_col6, #T_9ea6b_row5_col0, #T_9ea6b_row5_col1, #T_9ea6b_row5_col2, #T_9ea6b_row5_col3, #T_9ea6b_row5_col4, #T_9ea6b_row5_col5, #T_9ea6b_row5_col6, #T_9ea6b_row6_col0, #T_9ea6b_row6_col1, #T_9ea6b_row6_col2, #T_9ea6b_row6_col3, #T_9ea6b_row6_col4, #T_9ea6b_row6_col5, #T_9ea6b_row6_col6, #T_9ea6b_row7_col0, #T_9ea6b_row7_col1, #T_9ea6b_row7_col2, #T_9ea6b_row7_col3, #T_9ea6b_row7_col4, #T_9ea6b_row7_col5, #T_9ea6b_row7_col6, #T_9ea6b_row8_col0, #T_9ea6b_row8_col1, #T_9ea6b_row8_col2, #T_9ea6b_row8_col3, #T_9ea6b_row8_col4, #T_9ea6b_row8_col5, #T_9ea6b_row8_col6, #T_9ea6b_row9_col0, #T_9ea6b_row9_col1, #T_9ea6b_row9_col2, #T_9ea6b_row9_col3, #T_9ea6b_row9_col4, #T_9ea6b_row9_col5, #T_9ea6b_row9_col6, #T_9ea6b_row10_col0, #T_9ea6b_row10_col1, #T_9ea6b_row10_col2, #T_9ea6b_row10_col3, #T_9ea6b_row10_col4, #T_9ea6b_row10_col5, #T_9ea6b_row10_col6, #T_9ea6b_row11_col0, #T_9ea6b_row11_col1, #T_9ea6b_row11_col2, #T_9ea6b_row11_col3, #T_9ea6b_row11_col4, #T_9ea6b_row11_col5, #T_9ea6b_row11_col6, #T_9ea6b_row12_col0, #T_9ea6b_row12_col1, #T_9ea6b_row12_col2, #T_9ea6b_row12_col3, #T_9ea6b_row12_col4, #T_9ea6b_row12_col5, #T_9ea6b_row12_col6, #T_9ea6b_row13_col0, #T_9ea6b_row13_col1, #T_9ea6b_row13_col2, #T_9ea6b_row13_col3, #T_9ea6b_row13_col4, #T_9ea6b_row13_col5, #T_9ea6b_row13_col6, #T_9ea6b_row14_col0, #T_9ea6b_row14_col1, #T_9ea6b_row14_col2, #T_9ea6b_row14_col3, #T_9ea6b_row14_col4, #T_9ea6b_row14_col5, #T_9ea6b_row14_col6, #T_9ea6b_row15_col0, #T_9ea6b_row15_col1, #T_9ea6b_row15_col2, #T_9ea6b_row15_col3, #T_9ea6b_row15_col4, #T_9ea6b_row15_col5, #T_9ea6b_row15_col6, #T_9ea6b_row16_col0, #T_9ea6b_row16_col1, #T_9ea6b_row16_col2, #T_9ea6b_row16_col3, #T_9ea6b_row16_col4, #T_9ea6b_row16_col5, #T_9ea6b_row16_col6, #T_9ea6b_row17_col0, #T_9ea6b_row17_col1, #T_9ea6b_row17_col2, #T_9ea6b_row17_col3, #T_9ea6b_row17_col4, #T_9ea6b_row17_col5, #T_9ea6b_row17_col6 {
#   text-align: left;
# }
# #T_9ea6b_row0_col1, #T_9ea6b_row0_col2, #T_9ea6b_row0_col3, #T_9ea6b_row0_col4, #T_9ea6b_row0_col5, #T_9ea6b_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_9ea6b_row0_col7, #T_9ea6b_row1_col7, #T_9ea6b_row2_col7, #T_9ea6b_row3_col7, #T_9ea6b_row4_col7, #T_9ea6b_row5_col7, #T_9ea6b_row6_col7, #T_9ea6b_row7_col7, #T_9ea6b_row9_col7, #T_9ea6b_row10_col7, #T_9ea6b_row11_col7, #T_9ea6b_row12_col7, #T_9ea6b_row13_col7, #T_9ea6b_row14_col7, #T_9ea6b_row15_col7, #T_9ea6b_row16_col7, #T_9ea6b_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_9ea6b_row8_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_9ea6b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9ea6b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_9ea6b_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_9ea6b_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_9ea6b_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_9ea6b_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_9ea6b_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_9ea6b_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_9ea6b_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9ea6b_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_9ea6b_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_9ea6b_row0_col1" class="data row0 col1" >17062.4064</td>
#       <td id="T_9ea6b_row0_col2" class="data row0 col2" >789040304.7019</td>
#       <td id="T_9ea6b_row0_col3" class="data row0 col3" >27411.3775</td>
#       <td id="T_9ea6b_row0_col4" class="data row0 col4" >0.8789</td>
#       <td id="T_9ea6b_row0_col5" class="data row0 col5" >0.1364</td>
#       <td id="T_9ea6b_row0_col6" class="data row0 col6" >0.0983</td>
#       <td id="T_9ea6b_row0_col7" class="data row0 col7" >0.7780</td>
#     </tr>
#     <tr>
#       <th id="T_9ea6b_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_9ea6b_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_9ea6b_row1_col1" class="data row1 col1" >17573.5682</td>
#       <td id="T_9ea6b_row1_col2" class="data row1 col2" >982714901.3682</td>
#       <td id="T_9ea6b_row1_col3" class="data row1 col3" >30318.2912</td>
#       <td id="T_9ea6b_row1_col4" class="data row1 col4" >0.8539</td>
#       <td id="T_9ea6b_row1_col5" class="data row1 col5" >0.1448</td>
#       <td id="T_9ea6b_row1_col6" class="data row1 col6" >0.1023</td>
#       <td id="T_9ea6b_row1_col7" class="data row1 col7" >0.7200</td>
#     </tr>
#     <tr>
#       <th id="T_9ea6b_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_9ea6b_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#       <td id="T_9ea6b_row2_col1" class="data row2 col1" >18558.7684</td>
#       <td id="T_9ea6b_row2_col2" class="data row2 col2" >1035873814.5819</td>
#       <td id="T_9ea6b_row2_col3" class="data row2 col3" >31288.5652</td>
#       <td id="T_9ea6b_row2_col4" class="data row2 col4" >0.8447</td>
#       <td id="T_9ea6b_row2_col5" class="data row2 col5" >0.1525</td>
#       <td id="T_9ea6b_row2_col6" class="data row2 col6" >0.1097</td>
#       <td id="T_9ea6b_row2_col7" class="data row2 col7" >0.9380</td>
#     </tr>
#     <tr>
#       <th id="T_9ea6b_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_9ea6b_row3_col0" class="data row3 col0" >Extra Trees Regressor</td>
#       <td id="T_9ea6b_row3_col1" class="data row3 col1" >18501.1425</td>
#       <td id="T_9ea6b_row3_col2" class="data row3 col2" >1170340393.0537</td>
#       <td id="T_9ea6b_row3_col3" class="data row3 col3" >32818.1099</td>
#       <td id="T_9ea6b_row3_col4" class="data row3 col4" >0.8309</td>
#       <td id="T_9ea6b_row3_col5" class="data row3 col5" >0.1498</td>
#       <td id="T_9ea6b_row3_col6" class="data row3 col6" >0.1078</td>
#       <td id="T_9ea6b_row3_col7" class="data row3 col7" >0.8840</td>
#     </tr>
#     <tr>
#       <th id="T_9ea6b_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_9ea6b_row4_col0" class="data row4 col0" >AdaBoost Regressor</td>
#       <td id="T_9ea6b_row4_col1" class="data row4 col1" >24708.2228</td>
#       <td id="T_9ea6b_row4_col2" class="data row4 col2" >1244401593.5016</td>
#       <td id="T_9ea6b_row4_col3" class="data row4 col3" >34893.4518</td>
#       <td id="T_9ea6b_row4_col4" class="data row4 col4" >0.8112</td>
#       <td id="T_9ea6b_row4_col5" class="data row4 col5" >0.2003</td>
#       <td id="T_9ea6b_row4_col6" class="data row4 col6" >0.1604</td>
#       <td id="T_9ea6b_row4_col7" class="data row4 col7" >0.7960</td>
#     </tr>
#     <tr>
#       <th id="T_9ea6b_level0_row5" class="row_heading level0 row5" >huber</th>
#       <td id="T_9ea6b_row5_col0" class="data row5 col0" >Huber Regressor</td>
#       <td id="T_9ea6b_row5_col1" class="data row5 col1" >21935.6745</td>
#       <td id="T_9ea6b_row5_col2" class="data row5 col2" >1493659352.3201</td>
#       <td id="T_9ea6b_row5_col3" class="data row5 col3" >37319.8228</td>
#       <td id="T_9ea6b_row5_col4" class="data row5 col4" >0.7799</td>
#       <td id="T_9ea6b_row5_col5" class="data row5 col5" >0.1919</td>
#       <td id="T_9ea6b_row5_col6" class="data row5 col6" >0.1240</td>
#       <td id="T_9ea6b_r
# GradientBoostingRegressor(random_state=123)

# %% [markdown]
# Definindo o modelo Gradient Boosting Regressor	como uma variavel do SKlearn

# %%
gbr = create_model('gbr')
# Out:
# <style type="text/css">
# #T_d06a5_row10_col0, #T_d06a5_row10_col1, #T_d06a5_row10_col2, #T_d06a5_row10_col3, #T_d06a5_row10_col4, #T_d06a5_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_d06a5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d06a5_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_d06a5_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_d06a5_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_d06a5_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_d06a5_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_d06a5_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d06a5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d06a5_row0_col0" class="data row0 col0" >19893.0338</td>
#       <td id="T_d06a5_row0_col1" class="data row0 col1" >1725055138.3597</td>
#       <td id="T_d06a5_row0_col2" class="data row0 col2" >41533.7831</td>
#       <td id="T_d06a5_row0_col3" class="data row0 col3" >0.7893</td>
#       <td id="T_d06a5_row0_col4" class="data row0 col4" >0.1727</td>
#       <td id="T_d06a5_row0_col5" class="data row0 col5" >0.1098</td>
#     </tr>
#     <tr>
#       <th id="T_d06a5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d06a5_row1_col0" class="data row1 col0" >17271.7438</td>
#       <td id="T_d06a5_row1_col1" class="data row1 col1" >907318459.9355</td>
#       <td id="T_d06a5_row1_col2" class="data row1 col2" >30121.7274</td>
#       <td id="T_d06a5_row1_col3" class="data row1 col3" >0.8584</td>
#       <td id="T_d06a5_row1_col4" class="data row1 col4" >0.1286</td>
#       <td id="T_d06a5_row1_col5" class="data row1 col5" >0.0884</td>
#     </tr>
#     <tr>
#       <th id="T_d06a5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d06a5_row2_col0" class="data row2 col0" >15055.9986</td>
#       <td id="T_d06a5_row2_col1" class="data row2 col1" >453183129.0454</td>
#       <td id="T_d06a5_row2_col2" class="data row2 col2" >21288.0983</td>
#       <td id="T_d06a5_row2_col3" class="data row2 col3" >0.9019</td>
#       <td id="T_d06a5_row2_col4" class="data row2 col4" >0.1261</td>
#       <td id="T_d06a5_row2_col5" class="data row2 col5" >0.0943</td>
#     </tr>
#     <tr>
#       <th id="T_d06a5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d06a5_row3_col0" class="data row3 col0" >15655.7549</td>
#       <td id="T_d06a5_row3_col1" class="data row3 col1" >607597567.6317</td>
#       <td id="T_d06a5_row3_col2" class="data row3 col2" >24649.4943</td>
#       <td id="T_d06a5_row3_col3" class="data row3 col3" >0.8829</td>
#       <td id="T_d06a5_row3_col4" class="data row3 col4" >0.1256</td>
#       <td id="T_d06a5_row3_col5" class="data row3 col5" >0.0901</td>
#     </tr>
#     <tr>
#       <th id="T_d06a5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d06a5_row4_col0" class="data row4 col0" >18511.6683</td>
#       <td id="T_d06a5_row4_col1" class="data row4 col1" >886099129.0064</td>
#       <td id="T_d06a5_row4_col2" class="data row4 col2" >29767.4172</td>
#       <td id="T_d06a5_row4_col3" class="data row4 col3" >0.9099</td>
#       <td id="T_d06a5_row4_col4" class="data row4 col4" >0.1711</td>
#       <td id="T_d06a5_row4_col5" class="data row4 col5" >0.1219</td>
#     </tr>
#     <tr>
#       <th id="T_d06a5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d06a5_row5_col0" class="data row5 col0" >14823.6981</td>
#       <td id="T_d06a5_row5_col1" class="data row5 col1" >444000729.3459</td>
#       <td id="T_d06a5_row5_col2" class="data row5 col2" >21071.3248</td>
#       <td id="T_d06a5_row5_col3" class="data row5 col3" >0.9385</td>
#       <td id="T_d06a5_row5_col4" class="data row5 col4" >0.1235</td>
#       <td id="T_d06a5_row5_col5" class="data row5 col5" >0.0900</td>
#     </tr>
#     <tr>
#       <th id="T_d06a5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d06a5_row6_col0" class="data row6 col0" >19048.4575</td>
#       <td id="T_d06a5_row6_col1" class="data row6 col1" >807780678.4943</td>
#       <td id="T_d06a5_row6_col2" class="data row6 col2" >28421.4827</td>
#       <td id="T_d06a5_row6_col3" class="data row6 col3" >0.8287</td>
#       <td id="T_d06a5_row6_col4" class="data row6 col4" >0.1290</td>
#       <td id="T_d06a5_row6_col5" class="data row6 col5" >0.1013</td>
#     </tr>
#     <tr>
#       <th id="T_d06a5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d06a5_row7_col0" class="data row7 col0" >16190.1123</td>
#       <td id="T_d06a5_row7_col1" class="data row7 col1" >541688136.1101</td>
#       <td id="T_d06a5_row7_col2" class="data row7 col2" >23274.1946</td>
#       <td id="T_d06a5_row7_col3" class="data row7 col3" >0.9205</td>
#       <td id="T_d06a5_row7_col4" class="data row7 col4" >0.1283</td>
#       <td id="T_d06a5_row7_col5" class="data row7 col5" >0.0955</td>
#     </tr>
#     <tr>
#       <th id="T_d06a5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d06a5_row8_col0" class="data row8 col0" >19596.7702</td>
#       <td id="T_d06a5_row8_col1" class="data row8 col1" >1055573848.5504</td>
#       <td id="T_d06a5_row8_col2" class="data row8 col2" >32489.5960</td>
#       <td id="T_d06a5_row8_col3" class="data row8 col3" >0.8425</td>
#       <td id="T_d06a5_row8_col4" class="data row8 col4" >0.1500</td>
#       <td id="T_d06a5_row8_col5" class="data row8 col5" >0.1105</td>
#     </tr>
#     <tr>
#       <th id="T_d06a5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d06a5_row9_col0" class="data row9 col0" >14576.8263</td>
#       <td id="T_d06a5_row9_col1" class="data row9 col1" >462106230.5396</td>
#       <td id="T_d06a5_row9_col2" class="data row9 col2" >21496.6563</td>
#       <td id="T_d06a5_row9_col3" class="data row9 col3" >0.9163</td>
#       <td id="T_d06a5_row9_col4" class="data row9 col4" >0.1096</td>
#       <td id="T_d06a5_row9_col5" class="data row9 col5" >0.0814</td>
#     </tr>
#     <tr>
#       <th id="T_d06a5_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_d06a5_row10_col0" class="data row10 col0" >17062.4064</td>
#       <td id="T_d06a5_row10_col1" class="data row10 col1" >789040304.7019</td>
#       <td id="T_d06a5_row10_col2" class="data row10 col2" >27411.3775</td>
#       <td id="T_d06a5_row10_col3" class="data row10 col3" >0.8789</td>
#       <td id="T_d06a5_row10_col4" class="data row10 col4" >0.1364</td>
#       <td id="T_d06a5_row10_col5" class="data row10 col5" >0.0983</td>
#     </tr>
#     <tr>
#       <th id="T_d06a5_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_d06a5_row11_col0" class="data row11 col0" >1961.6114</td>
#       <td id="T_d06a5_row11_col1" class="data row11 col1" >374668925.8275</td>
#       <td id="T_d06a5_row11_col2" class="data row11 col2" >6136.5047</td>
#       <td id="T_d06a5_row11_col3" class="data row11 col3" >0.0453</td>
#       <td id="T_d06a5_row11_col4" class="data row11 col4" >0.0200</td>
#       <td id="T_d06a5_row11_col5" class="data row11 col5" >0.0118</td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 2
#       1 gbr = create_model('gbr')
# ----> 2 gbr.analyze_model(gbr)
#
# AttributeError: 'GradientBoostingRegressor' object has no attribute 'analyze_model'

# %%
evaluate_model(gbr)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
tuned_gbr = tune_model(gbr)
# Out:
# <style type="text/css">
# #T_44dd7_row10_col0, #T_44dd7_row10_col1, #T_44dd7_row10_col2, #T_44dd7_row10_col3, #T_44dd7_row10_col4, #T_44dd7_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_44dd7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_44dd7_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_44dd7_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_44dd7_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_44dd7_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_44dd7_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_44dd7_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_44dd7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_44dd7_row0_col0" class="data row0 col0" >23286.3062</td>
#       <td id="T_44dd7_row0_col1" class="data row0 col1" >2511127284.4892</td>
#       <td id="T_44dd7_row0_col2" class="data row0 col2" >50111.1493</td>
#       <td id="T_44dd7_row0_col3" class="data row0 col3" >0.6933</td>
#       <td id="T_44dd7_row0_col4" class="data row0 col4" >0.2086</td>
#       <td id="T_44dd7_row0_col5" class="data row0 col5" >0.1384</td>
#     </tr>
#     <tr>
#       <th id="T_44dd7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_44dd7_row1_col0" class="data row1 col0" >17462.9421</td>
#       <td id="T_44dd7_row1_col1" class="data row1 col1" >700409440.6349</td>
#       <td id="T_44dd7_row1_col2" class="data row1 col2" >26465.2497</td>
#       <td id="T_44dd7_row1_col3" class="data row1 col3" >0.8907</td>
#       <td id="T_44dd7_row1_col4" class="data row1 col4" >0.1345</td>
#       <td id="T_44dd7_row1_col5" class="data row1 col5" >0.0947</td>
#     </tr>
#     <tr>
#       <th id="T_44dd7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_44dd7_row2_col0" class="data row2 col0" >16325.2191</td>
#       <td id="T_44dd7_row2_col1" class="data row2 col1" >575228848.7229</td>
#       <td id="T_44dd7_row2_col2" class="data row2 col2" >23983.9290</td>
#       <td id="T_44dd7_row2_col3" class="data row2 col3" >0.8755</td>
#       <td id="T_44dd7_row2_col4" class="data row2 col4" >0.1393</td>
#       <td id="T_44dd7_row2_col5" class="data row2 col5" >0.1025</td>
#     </tr>
#     <tr>
#       <th id="T_44dd7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_44dd7_row3_col0" class="data row3 col0" >17389.1846</td>
#       <td id="T_44dd7_row3_col1" class="data row3 col1" >637685273.3720</td>
#       <td id="T_44dd7_row3_col2" class="data row3 col2" >25252.4310</td>
#       <td id="T_44dd7_row3_col3" class="data row3 col3" >0.8771</td>
#       <td id="T_44dd7_row3_col4" class="data row3 col4" >0.1285</td>
#       <td id="T_44dd7_row3_col5" class="data row3 col5" >0.0991</td>
#     </tr>
#     <tr>
#       <th id="T_44dd7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_44dd7_row4_col0" class="data row4 col0" >19898.4140</td>
#       <td id="T_44dd7_row4_col1" class="data row4 col1" >1317908646.8867</td>
#       <td id="T_44dd7_row4_col2" class="data row4 col2" >36303.0115</td>
#       <td id="T_44dd7_row4_col3" class="data row4 col3" >0.8659</td>
#       <td id="T_44dd7_row4_col4" class="data row4 col4" >0.1601</td>
#       <td id="T_44dd7_row4_col5" class="data row4 col5" >0.1158</td>
#     </tr>
#     <tr>
#       <th id="T_44dd7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_44dd7_row5_col0" class="data row5 col0" >16560.3621</td>
#       <td id="T_44dd7_row5_col1" class="data row5 col1" >592445084.3583</td>
#       <td id="T_44dd7_row5_col2" class="data row5 col2" >24340.1948</td>
#       <td id="T_44dd7_row5_col3" class="data row5 col3" >0.9179</td>
#       <td id="T_44dd7_row5_col4" class="data row5 col4" >0.1498</td>
#       <td id="T_44dd7_row5_col5" class="data row5 col5" >0.1038</td>
#     </tr>
#     <tr>
#       <th id="T_44dd7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_44dd7_row6_col0" class="data row6 col0" >20806.7207</td>
#       <td id="T_44dd7_row6_col1" class="data row6 col1" >1025514371.6535</td>
#       <td id="T_44dd7_row6_col2" class="data row6 col2" >32023.6533</td>
#       <td id="T_44dd7_row6_col3" class="data row6 col3" >0.7825</td>
#       <td id="T_44dd7_row6_col4" class="data row6 col4" >0.1381</td>
#       <td id="T_44dd7_row6_col5" class="data row6 col5" >0.1087</td>
#     </tr>
#     <tr>
#       <th id="T_44dd7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_44dd7_row7_col0" class="data row7 col0" >17052.2353</td>
#       <td id="T_44dd7_row7_col1" class="data row7 col1" >630157489.6835</td>
#       <td id="T_44dd7_row7_col2" class="data row7 col2" >25102.9379</td>
#       <td id="T_44dd7_row7_col3" class="data row7 col3" >0.9075</td>
#       <td id="T_44dd7_row7_col4" class="data row7 col4" >0.1290</td>
#       <td id="T_44dd7_row7_col5" class="data row7 col5" >0.0955</td>
#     </tr>
#     <tr>
#       <th id="T_44dd7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_44dd7_row8_col0" class="data row8 col0" >19290.7715</td>
#       <td id="T_44dd7_row8_col1" class="data row8 col1" >1495787678.9687</td>
#       <td id="T_44dd7_row8_col2" class="data row8 col2" >38675.4144</td>
#       <td id="T_44dd7_row8_col3" class="data row8 col3" >0.7768</td>
#       <td id="T_44dd7_row8_col4" class="data row8 col4" >0.1641</td>
#       <td id="T_44dd7_row8_col5" class="data row8 col5" >0.1135</td>
#     </tr>
#     <tr>
#       <th id="T_44dd7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_44dd7_row9_col0" class="data row9 col0" >15409.5186</td>
#       <td id="T_44dd7_row9_col1" class="data row9 col1" >431448713.0951</td>
#       <td id="T_44dd7_row9_col2" class="data row9 col2" >20771.3436</td>
#       <td id="T_44dd7_row9_col3" class="data row9 col3" >0.9218</td>
#       <td id="T_44dd7_row9_col4" class="data row9 col4" >0.1150</td>
#       <td id="T_44dd7_row9_col5" class="data row9 col5" >0.0904</td>
#     </tr>
#     <tr>
#       <th id="T_44dd7_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_44dd7_row10_col0" class="data row10 col0" >18348.1674</td>
#       <td id="T_44dd7_row10_col1" class="data row10 col1" >991771283.1865</td>
#       <td id="T_44dd7_row10_col2" class="data row10 col2" >30302.9314</td>
#       <td id="T_44dd7_row10_col3" class="data row10 col3" >0.8509</td>
#       <td id="T_44dd7_row10_col4" class="data row10 col4" >0.1467</td>
#       <td id="T_44dd7_row10_col5" class="data row10 col5" >0.1062</td>
#     </tr>
#     <tr>
#       <th id="T_44dd7_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_44dd7_row11_col0" class="data row11 col0" >2302.7897</td>
#       <td id="T_44dd7_row11_col1" class="data row11 col1" >604809302.0580</td>
#       <td id="T_44dd7_row11_col2" class="data row11 col2" >8573.4257</td>
#       <td id="T_44dd7_row11_col3" class="data row11 col3" >0.0713</td>
#       <td id="T_44dd7_row11_col4" class="data row11 col4" >0.0250</td>
#       <td id="T_44dd7_row11_col5" class="data row11 col5" >0.0132</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
