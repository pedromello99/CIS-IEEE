# %%
import pandas as pd 
df = pd.read_csv('train.csv')
df = df.select_dtypes(exclude=['object'])
df.fillna(value=0, inplace=True)
df.describe()
# Out:
#                 Id   MSSubClass  ...       YrSold      SalePrice
# count  1460.000000  1460.000000  ...  1460.000000    1460.000000
# mean    730.500000    56.897260  ...  2007.815753  180921.195890
# std     421.610009    42.300571  ...     1.328095   79442.502883
# min       1.000000    20.000000  ...  2006.000000   34900.000000
# 25%     365.750000    20.000000  ...  2007.000000  129975.000000
# 50%     730.500000    50.000000  ...  2008.000000  163000.000000
# 75%    1095.250000    70.000000  ...  2009.000000  214000.000000
# max    1460.000000   190.000000  ...  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %% [markdown]
# Testar sem os parametros classificatórios.

# %%
# Define X and y
y = df.SalePrice
X = df.drop(['SalePrice'], axis=1).select_dtypes(exclude=['object'])

# %%
from sklearn.model_selection import train_test_split
# Dividir entre treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %% [markdown]
# Testar utilizando árvore de Decisão

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error
dt = DecisionTreeRegressor(random_state=0)
dt.fit(X_train, y_train)
y_pred = dt.predict(X_test)
print('MSE: ', mean_squared_error(y_test, y_pred))
# Out:
# MSE:  1792916634.4684932

# %%
test = pd.read_csv('test.csv')
test = test.select_dtypes(exclude=['object'])
test.fillna(value=0, inplace=True)
y_pred_test = dt.predict(test)
final = pd.DataFrame({'Id': test.Id, 'SalePrice': y_pred_test})
final.to_csv('submission.csv', index=False)

# %%
from pycaret.regression import *
import pandas as pd

df = pd.read_csv('train.csv')
df = df.select_dtypes(exclude=['object'])
df.describe()

exp = setup(df, target='SalePrice', session_id=123, use_gpu=True)
exp.compare_models()
# Out:
# <style type="text/css">
# #T_3bb33_row9_col1, #T_3bb33_row16_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_3bb33">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3bb33_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_3bb33_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3bb33_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3bb33_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_3bb33_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_3bb33_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3bb33_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_3bb33_row1_col1" class="data row1 col1" >SalePrice</td>
#     </tr>
#     <tr>
#       <th id="T_3bb33_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
gbr = create_model('gbr')
tuned_gbr = tune_model(gbr, optimize='RMSE')
# Out:
# <style type="text/css">
# #T_83532_row10_col0, #T_83532_row10_col1, #T_83532_row10_col2, #T_83532_row10_col3, #T_83532_row10_col4, #T_83532_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_83532">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_83532_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_83532_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_83532_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_83532_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_83532_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_83532_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
test = pd.read_csv('test.csv')
test = test.select_dtypes(exclude=['object'])
y_pred_test = exp.predict(test)
final = pd.DataFrame({'Id': test.Id, 'SalePrice': y_pred_test})
final.to_csv('submission_gbr.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 3
#       1 test = pd.read_csv('test.csv')
#       2 test = test.select_dtypes(exclude=['object'])
# ----> 3 y_pred_test = exp.predict(test)
#       4 final = pd.DataFrame({'Id': test.Id, 'SalePrice': y_pred_test})
#       5 final.to_csv('submission_gbr.csv', index=False)
#
# AttributeError: 'RegressionExperiment' object has no attribute 'predict'
